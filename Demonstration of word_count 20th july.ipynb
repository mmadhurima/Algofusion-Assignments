# %%
import word_count as wc
str1 = input()
# Out:
# The standard of television programmes for commercial purposes has steadily declined over the years. Many mega-series have taken the place of educational programmes. Even during the newscast, commercials are common. The majority of the programme revolves around music and soap operas based on popular Hindi films. The glitter of the programmes so captivates the youth and children that they become addicted to a cheap culture. As a result, they become disconnected from their own cultural heritage. The authorities of various TV channels should reconsider airing the programmes for their own benefit as well as the national interest.

# %%
a = wc.remove_punc(str1)
a
# Out:
# 'The standard of television programmes for commercial purposes has steadily declined over the years Many megaseries have taken the place of educational programmes Even during the newscast commercials are common The majority of the programme revolves around music and soap operas based on popular Hindi films The glitter of the programmes so captivates the youth and children that they become addicted to a cheap culture As a result they become disconnected from their own cultural heritage The authorities of various TV channels should reconsider airing the programmes for their own benefit as well as the national interest'

# %%
b = wc.word_split(a)
b
# Out:
# ['The',
#  'standard',
#  'of',
#  'television',
#  'programmes',
#  'for',
#  'commercial',
#  'purposes',
#  'has',
#  'steadily',
#  'declined',
#  'over',
#  'the',
#  'years',
#  'Many',
#  'megaseries',
#  'have',
#  'taken',
#  'the',
#  'place',
#  'of',
#  'educational',
#  'programmes',
#  'Even',
#  'during',
#  'the',
#  'newscast',
#  'commercials',
#  'are',
#  'common',
#  'The',
#  'majority',
#  'of',
#  'the',
#  'programme',
#  'revolves',
#  'around',
#  'music',
#  'and',
#  'soap',
#  'operas',
#  'based',
#  'on',
#  'popular',
#  'Hindi',
#  'films',
#  'The',
#  'glitter',
#  'of',
#  'the',
#  'programmes',
#  'so',
#  'captivates',
#  'the',
#  'youth',
#  'and',
#  'children',
#  'that',
#  'they',
#  'become',
#  'addicted',
#  'to',
#  'a',
#  'cheap',
#  'culture',
#  'As',
#  'a',
#  'result',
#  'they',
#  'become',
#  'disconnected',
#  'from',
#  'their',
#  'own',
#  'cultural',
#  'heritage',
#  'The',
#  'authorities',
#  'of',
#  'various',
# ...

# %%
c = wc.word_dict(b)
c
# Out:
# {'The': 4,
#  'standard': 1,
#  'of': 5,
#  'television': 1,
#  'programmes': 4,
#  'for': 2,
#  'commercial': 1,
#  'purposes': 1,
#  'has': 1,
#  'steadily': 1,
#  'declined': 1,
#  'over': 1,
#  'the': 8,
#  'years': 1,
#  'Many': 1,
#  'megaseries': 1,
#  'have': 1,
#  'taken': 1,
#  'place': 1,
#  'educational': 1,
#  'Even': 1,
#  'during': 1,
#  'newscast': 1,
#  'commercials': 1,
#  'are': 1,
#  'common': 1,
#  'majority': 1,
#  'programme': 1,
#  'revolves': 1,
#  'around': 1,
#  'music': 1,
#  'and': 2,
#  'soap': 1,
#  'operas': 1,
#  'based': 1,
#  'on': 1,
#  'popular': 1,
#  'Hindi': 1,
#  'films': 1,
#  'glitter': 1,
#  'so': 1,
#  'captivates': 1,
#  'youth': 1,
#  'children': 1,
#  'that': 1,
#  'they': 2,
#  'become': 2,
#  'addicted': 1,
#  'to': 1,
#  'a': 2,
#  'cheap': 1,
#  'culture': 1,
#  'As': 1,
#  'result': 1,
#  'disconnected': 1,
#  'from': 1,
#  'their': 2,
#  'own': 2,
#  'cultural': 1,
#  'heritage': 1,
#  'authorities': 1,
#  'various': 1,
# ...

# %%
d = wc.word_freq_table(c)
d
# Out:
#           word  no of occurences
# 0          The                 4
# 1     standard                 1
# 2           of                 5
# 3   television                 1
# 4   programmes                 4
# ..         ...               ...
# 67     benefit                 1
# 68          as                 2
# 69        well                 1
# 70    national                 1
# 71    interest                 1
#
# [72 rows x 2 columns]
